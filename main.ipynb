# %%
import random

skills = {
    "1": {"name": "attack", "type": "damage", "value": (10, 20)},
    "2": {"name": "punchofluck", "type": "damage", "value": (0, 50)},
    "3": {"name": "heal", "type": "heal", "value": 25},
    "4": {"name": "defend", "type": "defend"}
}

# %%
def get_player_action():
    while True:
        print("\nChoose action:")
        print("[1] Attack ⚔️")
        print("[2] Punch of Luck 🍀")
        print("[3] Heal 💊")
        print("[4] Defend 🛡️")

        choice = input("Enter number (1-4): ").strip()

        if choice in skills:
            return choice
        else:
            print("❌ Invalid input! Try again.")

# %%
def main():
    player_hp = 100
    enemy_hp = 100
    player_status = {"defend": False}

    turn = 1

    print("⚔️ === Turn-Based Battle Game === ⚔️")

    while player_hp > 0 and enemy_hp > 0:
        print(f"\n--- Turn {turn} ---")
        print(f"❤️ Player HP: {player_hp} | 👾 Enemy HP: {enemy_hp}")

        # ===== Player Turn =====
        choice = get_player_action()
        skill = skills[choice]

        if skill["type"] == "damage":
            damage = random.randint(*skill["value"])
            enemy_hp -= damage
            print(f"\n⚔️ You used {skill['name']} and deal {damage} damage!")

        elif skill["type"] == "heal":
            player_hp = min(player_hp + skill["value"], 100)
            print(f"\n💊 You heal for {skill['value']} HP!")

        elif skill["type"] == "defend":
            player_status["defend"] = True
            print("\n🛡️ You are defending this turn!")

        # ===== Check Enemy Dead =====
        if enemy_hp <= 0:
            print("\n🎉 You Win!")
            break

        # ===== Enemy Turn =====
        if enemy_hp < 30:
            enemy_action = "heal"
        else:
            enemy_action = random.choice(["attack", "attack", "heal"])

        if enemy_action == "attack":
            damage = random.randint(10, 30)

            if player_status["defend"]:
                damage //= 2
                player_status["defend"] = False
                print("🛡️ You reduced the damage!")

            player_hp -= damage
            print(f"👾 Enemy attacks and deals {damage} damage!")

        else:
            heal = 15
            enemy_hp = min(enemy_hp + heal, 100)
            print(f"👾 Enemy heals for {heal} HP!")

        # ===== Check Player Dead =====
        if player_hp <= 0:
            print("\n💀 You Lose!")
            break

        turn += 1

    print("\n=== END ===")

# %% [markdown]
# # Run Program

# %%
main()
# Out:
# ⚔️ === Turn-Based Battle Game === ⚔️
#
# --- Turn 1 ---
# ❤️ Player HP: 100 | 👾 Enemy HP: 100
#
# Choose action:
# [1] Attack ⚔️
# [2] Punch of Luck 🍀
# [3] Heal 💊
# [4] Defend 🛡️
#
# ⚔️ You used attack and deal 10 damage!
# 👾 Enemy heals for 15 HP!
#
# --- Turn 2 ---
# ❤️ Player HP: 100 | 👾 Enemy HP: 100
#
# Choose action:
# [1] Attack ⚔️
# [2] Punch of Luck 🍀
# [3] Heal 💊
# [4] Defend 🛡️
#
# ⚔️ You used attack and deal 19 damage!
# 👾 Enemy attacks and deals 23 damage!
#
# --- Turn 3 ---
# ❤️ Player HP: 77 | 👾 Enemy HP: 81
#
# Choose action:
# [1] Attack ⚔️
# [2] Punch of Luck 🍀
# [3] Heal 💊
# [4] Defend 🛡️
#
# ⚔️ You used attack and deal 16 damage!
# 👾 Enemy heals for 15 HP!
#
# --- Turn 4 ---
# ❤️ Player HP: 77 | 👾 Enemy HP: 80
#
# Choose action:
# [1] Attack ⚔️
# [2] Punch of Luck 🍀
# [3] Heal 💊
# [4] Defend 🛡️
#
# ⚔️ You used attack and deal 10 damage!
# 👾 Enemy attacks and deals 24 damage!
#
# --- Turn 5 ---
# ❤️ Player HP: 53 | 👾 Enemy HP: 70
#
# Choose action:
# [1] Attack ⚔️
# [2] Punch of Luck 🍀
# [3] Heal 💊
# [4] Defend 🛡️
#
# ⚔️ You used attack and deal 17 damage!
# 👾 Enemy attacks and deals 21 damage!
#
# --- Turn 6 ---
# ❤️ Player HP: 32 | 👾 Enemy HP: 53
#
# Choose action:
# [1] Attack ⚔️
# [2] Punch of Luck 🍀
# [3] Heal 💊
# [4] Defend 🛡️
#
# ⚔️ You used attack and deal 19 damage!
# 👾 Enemy heals for 15 HP!
#
# --- Turn 7 ---
# ❤️ Player HP: 32 | 👾 Enemy HP: 49
#
# Choose action:
# [1] Attack ⚔️
# [2] Punch of Luck 🍀
# [3] Heal 💊
# [4] Defend 🛡️
#
# ⚔️ You used attack and deal 19 damage!
# 👾 Enemy attacks and deals 16 damage!
#
# --- Turn 8 ---
# ❤️ Player HP: 16 | 👾 Enemy HP: 30
#
# Choose action:
# [1] Attack ⚔️
# [2] Punch of Luck 🍀
# [3] Heal 💊
# [4] Defend 🛡️
#
# 💊 You heal for 25 HP!
# 👾 Enemy attacks and deals 14 damage!
#
# --- Turn 9 ---
# ❤️ Player HP: 27 | 👾 Enemy HP: 30
#
# Choose action:
# [1] Attack ⚔️
# [2] Punch of Luck 🍀
# [3] Heal 💊
# [4] Defend 🛡️
#
# 💊 You heal for 25 HP!
# 👾 Enemy attacks and deals 27 damage!
#
# --- Turn 10 ---
# ❤️ Player HP: 25 | 👾 Enemy HP: 30
#
# Choose action:
# [1] Attack ⚔️
# [2] Punch of Luck 🍀
# [3] Heal 💊
# [4] Defend 🛡️
#
# 💊 You heal for 25 HP!
# 👾 Enemy attacks and deals 19 damage!
#
# --- Turn 11 ---
# ❤️ Player HP: 31 | 👾 Enemy HP: 30
#
# Choose action:
# [1] Attack ⚔️
# [2] Punch of Luck 🍀
# [3] Heal 💊
# [4] Defend 🛡️
#
# 💊 You heal for 25 HP!
# 👾 Enemy attacks and deals 15 damage!
#
# --- Turn 12 ---
# ❤️ Player HP: 41 | 👾 Enemy HP: 30
#
# Choose action:
# [1] Attack ⚔️
# [2] Punch of Luck 🍀
# [3] Heal 💊
# [4] Defend 🛡️
#
# 💊 You heal for 25 HP!
# 👾 Enemy heals for 15 HP!
#
# --- Turn 13 ---
# ❤️ Player HP: 66 | 👾 Enemy HP: 45
#
# Choose action:
# [1] Attack ⚔️
# [2] Punch of Luck 🍀
# [3] Heal 💊
# [4] Defend 🛡️
#
# 💊 You heal for 25 HP!
# 👾 Enemy attacks and deals 25 damage!
#
# --- Turn 14 ---
# ❤️ Player HP: 66 | 👾 Enemy HP: 45
#
# Choose action:
# [1] Attack ⚔️
# [2] Punch of Luck 🍀
# [3] Heal 💊
# [4] Defend 🛡️
#
# ⚔️ You used punchofluck and deal 21 damage!
# 👾 Enemy heals for 15 HP!
#
# --- Turn 15 ---
# ❤️ Player HP: 66 | 👾 Enemy HP: 39
#
# Choose action:
# [1] Attack ⚔️
# [2] Punch of Luck 🍀
# [3] Heal 💊
# [4] Defend 🛡️
#
# ⚔️ You used attack and deal 10 damage!
# 👾 Enemy heals for 15 HP!
#
# --- Turn 16 ---
# ❤️ Player HP: 66 | 👾 Enemy HP: 44
#
# Choose action:
# [1] Attack ⚔️
# [2] Punch of Luck 🍀
# [3] Heal 💊
# [4] Defend 🛡️
#
# ⚔️ You used attack and deal 15 damage!
# 👾 Enemy heals for 15 HP!
#
# --- Turn 17 ---
# ❤️ Player HP: 66 | 👾 Enemy HP: 44
#
# Choose action:
# [1] Attack ⚔️
# [2] Punch of Luck 🍀
# [3] Heal 💊
# [4] Defend 🛡️
#
# ⚔️ You used attack and deal 11 damage!
# 👾 Enemy attacks and deals 22 damage!
#
# --- Turn 18 ---
# ❤️ Player HP: 44 | 👾 Enemy HP: 33
#
# Choose action:
# [1] Attack ⚔️
# [2] Punch of Luck 🍀
# [3] Heal 💊
# [4] Defend 🛡️
#
# ⚔️ You used attack and deal 19 damage!
# 👾 Enemy heals for 15 HP!
#
# --- Turn 19 ---
# ❤️ Player HP: 44 | 👾 Enemy HP: 29
#
# Choose action:
# [1] Attack ⚔️
# [2] Punch of Luck 🍀
# [3] Heal 💊
# [4] Defend 🛡️
#
# ⚔️ You used punchofluck and deal 38 damage!
#
# 🎉 You Win!
#
# === END ===
